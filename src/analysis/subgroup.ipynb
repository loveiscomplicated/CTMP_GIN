# %%
import os
import pandas as pd
cur_dir = os.getcwd()
raw_data_path = os.path.join("..", "data", "raw", "TEDS_Discharge.csv")
raw_df = pd.read_csv(raw_data_path)

# %%
len(raw_df.columns)
# Out:
# 76

# %%
len(raw_df.columns) - 2 - 1 - 60
# Out:
# 13
