# %%
import os
import pandas as pd
cur_dir = os.getcwd()
raw_data_path = os.path.join("..", "data", "raw", "TEDS_Discharge.csv")
raw_df = pd.read_csv(raw_data_path)
w_all = pd.read_csv("Gated_Fusion_weight_seed_1_all.csv", index_col=0)

# %%
w_all["LOS"] = raw_df["LOS"]
w_all
# Out:
#              w_ad     w_dis  w_merged  LOS
# 0        0.197252  0.570065  0.232683   36
# 1        0.950627  0.023891  0.025481    1
# 2        0.257958  0.577605  0.164438   34
# 3        0.027725  0.341697  0.630578   36
# 4        0.114644  0.288243  0.597114   37
# ...           ...       ...       ...  ...
# 1393915  0.107406  0.502378  0.390216   30
# 1393916  0.235405  0.587534  0.177061   27
# 1393917  0.532636  0.379189  0.088175    4
# 1393918  0.411195  0.289344  0.299461   22
# 1393919  0.022701  0.664698  0.312601   35
#
# [1393920 rows x 4 columns]
